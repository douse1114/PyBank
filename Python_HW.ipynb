# %%
import pandas as pd
import os
os.getcwd()
# Out:
# 'C:\\Users\\iced2\\asu-tem-virt-fin-pt-04-2021-u-c\\Homework\\02-Python\\Instructions'

# %%
os.listdir(os.getcwd())
# Out:
# ['.ipynb_checkpoints',
#  'FinTech_Unit_2_Homework_ Grading_Rubric - PyBank.pdf',
#  'FinTech_Unit_2_Homework_ Grading_Rubric.pdf',
#  'Images',
#  'PyBank',
#  'PyRamen',
#  'README.md',
#  'Untitled.ipynb']

# %%
cd PyBank/
# Out:
# C:\Users\iced2\asu-tem-virt-fin-pt-04-2021-u-c\Homework\02-Python\Instructions\PyBank

# %%
cd Resources/
# Out:
# C:\Users\iced2\asu-tem-virt-fin-pt-04-2021-u-c\Homework\02-Python\Instructions\PyBank\Resources

# %%
import pandas as pd
import os
os.getcwd()
# Out:
# 'C:\\Users\\iced2\\asu-tem-virt-fin-pt-04-2021-u-c\\Homework\\02-Python\\Instructions\\PyBank\\Resources'

# %%
os.listdir(os.getcwd())
# Out:
# ['.ipynb_checkpoints', 'budget_data.csv']

# %%
pd.read_csv('budget_data.csv')
# Out:
#         Date  Profit/Losses
# 0   Jan-2010         867884
# 1   Feb-2010         984655
# 2   Mar-2010         322013
# 3   Apr-2010         -69417
# 4   May-2010         310503
# ..       ...            ...
# 81  Oct-2016         102685
# 82  Nov-2016         795914
# 83  Dec-2016          60988
# 84  Jan-2017         138230
# 85  Feb-2017         671099
#
# [86 rows x 2 columns]

# %%
import pandas
df = pandas.read_csv('budget_data.csv')
print(df)
# Out:
#         Date  Profit/Losses
# 0   Jan-2010         867884
# 1   Feb-2010         984655
# 2   Mar-2010         322013
# 3   Apr-2010         -69417
# 4   May-2010         310503
# ..       ...            ...
# 81  Oct-2016         102685
# 82  Nov-2016         795914
# 83  Dec-2016          60988
# 84  Jan-2017         138230
# 85  Feb-2017         671099
#
# [86 rows x 2 columns]

# %%
df.sum(axis = 1, skipna = True)
# Out:
# 0     867884
# 1     984655
# 2     322013
# 3     -69417
# 4     310503
#        ...
# 81    102685
# 82    795914
# 83     60988
# 84    138230
# 85    671099
# Length: 86, dtype: int64

# %%
import pandas
df = pandas.read_csv('budget_data.csv')
print(df)
# Out:
#         Date  Profit/Losses
# 0   Jan-2010         867884
# 1   Feb-2010         984655
# 2   Mar-2010         322013
# 3   Apr-2010         -69417
# 4   May-2010         310503
# ..       ...            ...
# 81  Oct-2016         102685
# 82  Nov-2016         795914
# 83  Dec-2016          60988
# 84  Jan-2017         138230
# 85  Feb-2017         671099
#
# [86 rows x 2 columns]

# %%
column_name = "Profit/Losses"
column_sum = df[column_name].sum()
print (column_sum)
# Out:
# 38382578

# %%
print(column_sum)
# Out:
# 38382578
